# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

features = ['MAE', 'RMSE', 'R-squared']
MAE = [14.7687, 13.6754]
RMSE = [21.6909, 20.8388]
Rsquared = [0.9943, 0.9953]
x = np.arange(len(features))
width = 0.10
fig, ax = plt.subplots()
ax.set_xlabel("Regressor Types")
ax.set_ylabel("Regressor Values")
ax.set_xticks(x, features)
ax.set_title("1 conv layer and 3 conv layers")
ax.legend()
fig.tight_layout()
plt.plot(x, features)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
