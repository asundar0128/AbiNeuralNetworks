# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(20)
smartgrid_data = np.random.normal(200, 40, 400)
boxplot = plt.figure(figsize = (10, 7))
plt.boxplot(smartgrid_data)
plt.show()
