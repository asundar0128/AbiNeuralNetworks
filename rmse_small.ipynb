# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker
from pylab import *

Regressors = ["RF", "DT", "SVR", "BR", "LR", "MLP", "CNN"]
RMSE = [17.563, 21.353, 24.64, 22.62, 22.62, 20.78, 20.994]
smartgrid_values = {"Regressors": Regressors, "RMSE": RMSE}
smartgrid_data = pd.DataFrame(smartgrid_values)
print(smartgrid_data)
smartgrid_data.plot(kind="box")
plt.xlabel("Regressors")
plt.ylabel("RMSE")
plt.title("Training Data Shape (700, 15) testing data shape (300, 15)")
plt.show()
# Out:
#   Regressors    RMSE
# 0         RF  17.563
# 1         DT  21.353
# 2        SVR  24.640
# 3         BR  22.620
# 4         LR  22.620
# 5        MLP  20.780
# 6        CNN  20.994
