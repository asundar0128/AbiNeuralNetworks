# %%
import matplotlib.pyplot as plt
regressors = ["Random Forest", "Linear Regression", "Decision Tree", "Multilayer Perceptron", "Support Vector Regression", "Convolutional Neural Network", "Bayesian Ridge", "RF"]
bins = [0.996, 0.993, 0.994, 0.994, 0.992, 0.995, 0.993, 0.996]
plt.hist(regressors, bins, histtype = "stepfilled", rwidth = 0.001)
plt.xlabel("Regressors")
plt.ylabel("R squared values")
plt.title("Histogram - Regressors and Respective R squared Values")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 regressors = ["Random Forest", "Linear Regression", "Decision Tree", "Multilayer Perceptron", "Support Vector Regression", "Convolutional Neural Network", "Bayesian Ridge", "RF"]
#       3 bins = [0.996, 0.993, 0.994, 0.994, 0.992, 0.995, 0.993, 0.996]
# ----> 4 plt.hist(regressors, bins, histtype = "stepfilled", rwidth = 0.001)
#       5 plt.xlabel("Regressors")
#       6 plt.ylabel("R squared values")
#
# File /lib/python3.10/site-packages/matplotlib/pyplot.py:2590, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2584 @_copy_docstring_and_deprecators(Axes.hist)
#    2585 def hist(
#    2586         x, bins=None, range=None, density=False, weights=None,
# ...
