# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0.34, 0.34, 0.56, 0.56])
regressionmethods = ['Random Forest', 'Linear Regression', 'Decision Tree', 'Multilayer Perceptron', 'Support Vector Regression', 'CNN', 'Bayesian Ridge', 'RF']
Rsquared = [0.996,0.993,0.994,0.994,0.992, 0.995, 0.993, 0.996]
RMSE = [17.563, 22.62, 21.353, 20.78, 24.64, 20.994, 22.62, 17.586]
MAE = [11.189, 17.63, 13.848, 14.28, 14.75, 14.63, 17.63, 11.219]
ax.bar(Rsquared, RMSE, MAE)
plt.xlabel("Regression Techniques")
plt.ylabel("Methods of Measurement for Smart Grids")
plt.show()
