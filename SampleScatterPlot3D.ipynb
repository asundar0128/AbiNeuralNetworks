# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Number of Quarks Per Unit Of Charge")
plt.xlabel("Value of Quarks")
plt.ylabel("Value of Unit Charge")
plt.show()
pd.set_option("display.max.columns", None)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 14>()
#      12 plt.ylabel("Value of Unit Charge")
#      13 plt.show()
# ---> 14 pd.set_option("display.max.columns", None)
#      15 df.head()
#
# NameError: name 'pd' is not defined
