# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker
from pylab import *

Regressors = ["RF", "DT", "SVR", "BR", "LR", "MLP", "CNN"]
Rsquared = [0.996, 0.994, 0.992, 0.993, 0.993, 0.994,  0.995]

smartgrid_values = {"Regressors": Regressors, "Rsquared": Rsquared}
smartgrid_data = pd.DataFrame(smartgrid_values)
print(smartgrid_data)
smartgrid_data.plot(kind="box")
plt.xlabel("Regressors")
plt.ylabel("Rsquared")
plt.title("Test Results")
plt.show()

#plt.boxplot(smartgrid_data)
#plt.show()
# Out:
#   Regressors  Rsquared
# 0         RF     0.996
# 1         DT     0.994
# 2        SVR     0.992
# 3         BR     0.993
# 4         LR     0.993
# 5        MLP     0.994
# 6        CNN     0.995
